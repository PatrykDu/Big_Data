# %% [markdown]
# <a href="https://colab.research.google.com/github/PatrykDu/Big_Data/blob/main/intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello Colab')
# Out:
# Hello Colab

# %%
# Tekst
